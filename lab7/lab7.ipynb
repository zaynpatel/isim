# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('lab7-csv')
df
# Out:
#              t1       ch1         t2       ch2
# 0    -15.070625  0.009604 -15.070625  0.885216
# 1    -15.050625  0.004647 -15.050625  0.890186
# 2    -15.030625  0.004647 -15.030625  0.890186
# 3    -15.010625 -0.000310 -15.010625  0.905095
# 4    -14.990625  0.004647 -14.990625  0.924973
# ...         ...       ...        ...       ...
# 1495  14.829375 -0.000310  14.829375  0.885216
# 1496  14.849375 -0.000310  14.849375  0.900125
# 1497  14.869375 -0.000310  14.869375  0.900125
# 1498  14.889375 -0.005267  14.889375  0.890186
# 1499  14.909375 -0.000310  14.909375  0.885216
#
# [1500 rows x 4 columns]

# %% [markdown]
# **Caption:** I built a pluse oximeter circuit to track my pulse over time, reading Vout as voltage with Ch 2+. For the circuit, I used cutoff frequencies of 1 Hz and 10 Hz, for the high and low pass filter, respectively. And, I used 10 gain with an operational amplifier.

# %%
plt.figure().set_figwidth(20)
plt.plot(df['t2'], df['ch2'])
plt.xlabel('Time (seconds)')
plt.ylabel('Voltage (V)')
plt.title('Plot of Heartbeat over Time')
# Out:
# Text(0.5, 1.0, 'Plot of Heartbeat over Time')
