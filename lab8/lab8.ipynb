# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('lab8-finalplot')
df
# Out:
#              t1       ch1         t2       ch2
# 0    -15.694375 -2.003707 -15.694375 -0.928701
# 1    -15.674375 -2.006695 -15.674375 -0.928701
# 2    -15.654375 -2.004703 -15.654375 -0.928701
# 3    -15.634375 -2.006695 -15.634375 -0.918761
# 4    -15.614375 -2.006695 -15.614375 -0.923731
# ...         ...       ...        ...       ...
# 1495  14.205625 -0.028635  14.205625 -0.933670
# 1496  14.225625 -0.029631  14.225625 -0.933670
# 1497  14.245625 -0.048555  14.245625 -0.933670
# 1498  14.265625 -0.027639  14.265625 -0.923731
# 1499  14.285625 -0.018675  14.285625 -0.938640
#
# [1500 rows x 4 columns]

# %% [markdown]
# **Caption of graph:** This is a plot of voltage over time using the Ballistocardiograph circuit and instrumentation. The process to take this measurement was to attach the cables from the Ballistocardiograph to my circuit and pass the current through two bandpass filters and two low pass filters with three of these filters connected to the op-amp (which amplifies the current that's passed through it).

# %%
df2 = df['ch1'][1100:1499]
plt.figure().set_figwidth(20)
plt.plot(df2)
plt.xlabel('Time (Miliseconds)')
plt.ylabel('Voltage (mV)')
plt.title('A plot of Ballistocardiograph with Voltage plotted over time')
# Out:
# Text(0.5, 1.0, 'A plot of Ballistocardiograph with Voltage plotted over time')
