# %%
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('lab1-graph')
df
df2 = df.drop('t2', axis=1)
df3 = df2.drop('ch2', axis=1)
df3
# Out:
#              t1       ch1
# 0    -74.997000  0.292160
# 1    -74.897004  0.267375
# 2    -74.797008  0.242589
# 3    -74.697012  0.227718
# 4    -74.597016  0.217804
# ...         ...       ...
# 1495  74.497020  0.594545
# 1496  74.597016  0.579674
# 1497  74.697012  0.559845
# 1498  74.797008  0.544974
# 1499  74.897004  0.525145
#
# [1500 rows x 2 columns]

# %%
#time = df

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax.plot(df3.t1, df3.ch1)
ax.set_xlim([-75, 17.555])
# Out:
# (-75.0, 17.555)
